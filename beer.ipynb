# %%
import numpy as np
import pandas as pd

# %%
#beer1=pd.read_csv("Beer/beers.csv")

# %%
#beer1

# %%
beer2=pd.read_csv("Beer/beer_data_set.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 beer2=pd.read_csv("Beer/beer_data_set.csv")
#
# File c:\Users\valte\Documents\Bootcamp\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %%
beer2
# Out:
#                                              Name  key          Style  \
# 0                                           Amber  251        Altbier
# 1                                      Double Bag  252        Altbier
# 2                                  Long Trail Ale  253        Altbier
# 3                                    Doppelsticke  254        Altbier
# 4                                          Scurry  255        Altbier
# ...                                           ...  ...            ...
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#       Style Key                                  Brewery  \
# 0             8                      Alaskan Brewing Co.
# ...

# %%
beer1.columns=[col.replace(" ","_").lower() for col in beer1.columns]
beer2.columns=[col.replace(" ","_").lower() for col in beer2.columns]
beer2["ibu"] = beer2[["min_ibu", "max_ibu"]].mean(axis=1)
beer=pd.merge(beer2,beer1,on="name", how="left")

# %%
beer
beer.drop(columns=["key","brewery","description","min_ibu","max_ibu","unnamed:_0"], inplace=True)

# %%
beer.drop(columns=["ibu_x","abv_y","ibu_y","id","style_y","brewery_id","ounces"], inplace=True)

# %%
beer.nunique()
# Out:
# name           5317
# style_x         112
# style_key       112
# abv_x           229
# ave_rating      289
# astringency      73
# body            165
# alcohol         116
# bitter          141
# sweet           191
# sour            222
# salty            47
# fruits          185
# hoppy           156
# spices          155
# malty           217
# dtype: int64

# %%
beer.isna().sum()
# Out:
# name           2
# style_x        0
# style_key      0
# abv_x          0
# ave_rating     0
# astringency    0
# body           0
# alcohol        0
# bitter         0
# sweet          0
# sour           0
# salty          0
# fruits         0
# hoppy          0
# spices         0
# malty          0
# dtype: int64

# %%
beer.shape
# Out:
# (5663, 16)

# %%
#beer3=pd.read_csv("Beer/brewing_materials.csv")

# %%
beer
# Out:
#                                              name        style_x  style_key  \
# 0                                           Amber        Altbier          8
# 1                                      Double Bag        Altbier          8
# 2                                  Long Trail Ale        Altbier          8
# 3                                    Doppelsticke        Altbier          8
# 4                                          Scurry        Altbier          8
# ...                                           ...            ...        ...
# 5658                          Red Nose Winter Ale  Winter Warmer         17
# 5659  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer         17
# 5660                         Fish Tale Winterfish  Winter Warmer         17
# 5661    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer         17
# 5662     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer         17
#
# ...

# %%
#beer3=pd.read_csv("Beer/beer_states.csv")

# %%
#beer3
# Out:
#       state  year      barrels              type
# 0        AK  2008      2067.69       On Premises
# 1        AK  2009      2263.65       On Premises
# 2        AK  2010      1929.15       On Premises
# 3        AK  2011      2251.02       On Premises
# 4        AK  2012      2312.43       On Premises
# ...     ...   ...          ...               ...
# 1867  total  2015  17750504.62  Kegs and Barrels
# 1868  total  2016  17000382.28  Kegs and Barrels
# 1869  total  2017  16514866.69  Kegs and Barrels
# 1870  total  2018  15662381.42  Kegs and Barrels
# 1871  total  2019  14880067.09  Kegs and Barrels
#
# [1872 rows x 4 columns]

# %%
#beer4=pd.read_csv("Beer/brewer_size.csv")

# %%
#beer4
# Out:
#      year                         brewer_size  n_of_brewers  total_barrels  \
# 0    2009          6,000,001 Barrels and Over          18.0   1.712329e+08
# 1    2009  1,000,001 to 6,000,000 Barrels (5)           4.0   9.970404e+06
# 2    2009        500,001 to 1,000,000 Barrels           7.0   4.831386e+06
# 3    2009          100,001 to 500,000 Barrels          27.0   5.422156e+06
# 4    2009           60,001 to 100,000 Barrels          19.0   1.501977e+06
# ..    ...                                 ...           ...            ...
# 133  2019              1,001 to 7,500 Barrels        1183.0   3.151130e+06
# 134  2019                  1 to 1,000 Barrels        4577.0   1.321901e+06
# 135  2019                      Under 1 Barrel          28.0   1.830000e+01
# 136  2019                           0 Barrels         174.0            NaN
# 137  2019                               Total        6400.0   1.797202e+08
#
#      taxable_removals  total_shipped
# ...

# %%
beer.rename(columns= {"style_x": "type","abv_x":"abv","ave_rating":"rating"}, inplace=True)

# %%
beer
# Out:
#                                              name           type  style_key  \
# 0                                           Amber        Altbier          8
# 1                                      Double Bag        Altbier          8
# 2                                  Long Trail Ale        Altbier          8
# 3                                    Doppelsticke        Altbier          8
# 4                                          Scurry        Altbier          8
# ...                                           ...            ...        ...
# 5658                          Red Nose Winter Ale  Winter Warmer         17
# 5659  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer         17
# 5660                         Fish Tale Winterfish  Winter Warmer         17
# 5661    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer         17
# 5662     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer         17
#
# ...

# %%
beertype = pd.DataFrame({
    "type": beer["type"],
    "style_key": beer["style_key"]
})

print(beertype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 beertype = pd.DataFrame({
# ----> 2     "type": beer["type"],
#       3     "style_key": beer["style_key"]
#       4 })
#       6 print(beertype)
#
# NameError: name 'beer' is not defined

# %%
beer["type"].unique()
# Out:
# array(['Altbier', 'Barleywine - American', 'Barleywine - English',
#        'Bitter - English Extra Special / Strong Bitter (ESB)',
#        'Bitter - English', 'Bière de Champagne / Bière Brut',
#        'Blonde Ale - American', 'Blonde Ale - Belgian',
#        'Bock - Doppelbock', 'Bock - Eisbock', 'Bock - Maibock',
#        'Bock - Traditional', 'Bock - Weizenbock', 'Braggot', 'Brett Beer',
#        'Brown Ale - American', 'Brown Ale - Belgian Dark',
#        'Brown Ale - English', 'California Common / Steam Beer',
#        'Chile Beer', 'Cream Ale', 'Dubbel',
#        'Farmhouse Ale - Bière de Garde', 'Farmhouse Ale - Sahti',
#        'Farmhouse Ale - Saison', 'Fruit and Field Beer',
#        'Gruit / Ancient Herbed Ale', 'Happoshu', 'Herb and Spice Beer',
#        'IPA - American', 'IPA - Belgian',
#        'IPA - Black / Cascadian Dark Ale', 'IPA - Brut', 'IPA - English',
#        'IPA - Imperial', 'IPA - New England', 'Kvass', 'Kölsch',
# ...

# %%
with open('Beer/recipeData.csv', 'r', encoding='utf-8', errors='replace') as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 with open('Beer/recipeData.csv', 'r', encoding='utf-8', errors='replace') as file:
#       2     content = file.read()
#
# File c:\Users\valte\Documents\Bootcamp\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Beer/recipeData.csv'

# %%
beer6=pd.read_csv("Beer/Product_range.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 beer6=pd.read_csv("Beer/Product_range.csv")
#
# File c:\Users\valte\Documents\Bootcamp\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %%
beer6
# Out:
#       Product_code Vendor_code  \
# 0             5028         NaN
# 1             4846         NaN
# 2             1340         NaN
# 3             4372         NaN
# 4             4302         NaN
# ...            ...         ...
# 5309           868         NaN
# 5310          1861         NaN
# 5311          4724         NaN
# 5312           822     Bakunin
# 5313          1682         NaN
#
#                                                    Name  Retail_price  \
# 0                              1 Symbiotica Apple 0.375         300.0
# 1       1 Symbiotica Hard Kombucha Renegade Aronia 0.33         200.0
# 2                        1000 IBU Imperial IPA Barrel l         960.0
# 3                                   18th Street Brewery           NaN
# 4         18th Street Brewery Deal With The Devil 0.473         630.0
# ...                                                 ...           ...
# 5309                                   Spagetti Vestern         880.0
# ...

# %%
beer.duplicated().sum()
beer.drop_duplicates(inplace=True)

# %%
beer.shape
beer.duplicated().sum()
# Out:
# 0

# %%
## KNN

# %%
from sklearn.datasets import load_iris, fetch_california_housing
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
beer[["type","style_key"]].nunique()
# Out:
# type         112
# style_key    112
# dtype: int64

# %%
beer["style_key"].unique()
# Out:
# array([  8,  97,  98,  41,  40,  27,  43,  42,   2,   3,   4,   5,   6,
#         28, 117,   9,  10,  11,  29,  75,  30,  14,  44,  76,  45,  77,
#         78,  79,  80,  32,  33,  34,  35,  36,  37,  38,  81,  46,  54,
#         19,  55,  56,  20,  57,  58,  59,  60,  82,  61,  62,  63,  22,
#         21,  23,  24,  25, 118, 119, 120, 121,  83,  12,  47,  99,  48,
#         49,  50,  64,  65,  66,  68,  69,  70,  71,  72,  73,  84, 100,
#         51, 101,  52,  15,  85, 102,  16,  86, 122, 123, 124, 125,  89,
#         88,  90,  91,  92,  93,  94,  95, 103, 104, 105, 106, 107, 110,
#        111, 112, 113, 114, 108, 115, 126,  17], dtype=int64)

# %%
beer.head(50)
# Out:
#                                       name     type  style_key   abv  rating  \
# 0                                    Amber  Altbier          8  5.30    3.65
# 1                               Double Bag  Altbier          8  7.20    3.90
# 2                           Long Trail Ale  Altbier          8  5.00    3.58
# 3                             Doppelsticke  Altbier          8  8.50    4.15
# 4                                   Scurry  Altbier          8  5.30    3.67
# 5             Sleigh'r Dark Doüble Alt Ale  Altbier          8  7.20    3.78
# 6                                   Sticke  Altbier          8  6.00    4.10
# 7                        Okto Festival Ale  Altbier          8  5.30    3.46
# 8                      Southampton Altbier  Altbier          8  5.00    3.60
# 9                                   Copper  Altbier          8  4.80    4.10
# 10                     Organic Münster Alt  Altbier          8  5.10    3.70
# ...

# %%
beer.rename(columns= {"style_key": "type_id"}, inplace=True)

# %%
beer
# Out:
#                                              name           type  type_id  \
# 0                                           Amber        Altbier        8
# 1                                      Double Bag        Altbier        8
# 2                                  Long Trail Ale        Altbier        8
# 3                                    Doppelsticke        Altbier        8
# 4                                          Scurry        Altbier        8
# ...                                           ...            ...      ...
# 5658                          Red Nose Winter Ale  Winter Warmer       17
# 5659  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer       17
# 5660                         Fish Tale Winterfish  Winter Warmer       17
# 5661    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer       17
# 5662     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer       17
#
#       abv  rating  astringency  body  alcohol  bitter  sweet  sour  salty  \
# ...

# %%
beero=pd.read_csv("Beer/beer_profile_and_ratings.csv")

# %%
beero
# Out:
#                                           Name          Style  \
# 0                                        Amber        Altbier
# 1                                   Double Bag        Altbier
# 2                               Long Trail Ale        Altbier
# 3                                 Doppelsticke        Altbier
# 4                 Sleigh'r Dark Doüble Alt Ale        Altbier
# ...                                        ...            ...
# 3192                           Winter Shredder  Winter Warmer
# 3193                        The First Snow Ale  Winter Warmer
# 3194                       Red Nose Winter Ale  Winter Warmer
# 3195                      Fish Tale Winterfish  Winter Warmer
# 3196  Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
#                                                Brewery  \
# 0                                  Alaskan Brewing Co.
# 1                               Long Trail Brewing Co.
# ...

# %%
beero.columns=[col.replace(" ","_").lower() for col in beero.columns]
beero["ibu"] = beero[["min_ibu", "max_ibu"]].mean(axis=1)

# %%
beero.nunique()

beero.drop(columns=["beer_name_(full)","description","min_ibu","max_ibu"], inplace=True)
beero.rename(columns= {"style": "type","review_overall":"rating"}, inplace=True)

# %%
beero
# Out:
#                                           name           type  \
# 0                                        Amber        Altbier
# 1                                   Double Bag        Altbier
# 2                               Long Trail Ale        Altbier
# 3                                 Doppelsticke        Altbier
# 4                 Sleigh'r Dark Doüble Alt Ale        Altbier
# ...                                        ...            ...
# 3192                           Winter Shredder  Winter Warmer
# 3193                        The First Snow Ale  Winter Warmer
# 3194                       Red Nose Winter Ale  Winter Warmer
# 3195                      Fish Tale Winterfish  Winter Warmer
# 3196  Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
#                                                brewery  abv  astringency  \
# 0                                  Alaskan Brewing Co.  5.3           13
# ...

# %%
beer.head(5)
# Out:
#              name     type  type_id  abv  rating  astringency  body  alcohol  \
# 0           Amber  Altbier        8  5.3    3.65           13    32        9
# 1      Double Bag  Altbier        8  7.2    3.90           12    57       18
# 2  Long Trail Ale  Altbier        8  5.0    3.58           14    37        6
# 3    Doppelsticke  Altbier        8  8.5    4.15           13    55       31
# 4          Scurry  Altbier        8  5.3    3.67           21    69       10
#
#    bitter  sweet  sour  salty  fruits  hoppy  spices  malty
# 0      47     74    33      0      33     57       8    111
# 1      33     55    16      0      24     35      12     84
# 2      42     43    11      0      10     54       4     62
# 3      47    101    18      1      49     40      16    119
# 4      63    120    14      0      19     36      15    218

# %%
beero.head(5)
beero.drop(columns=["brewery"], inplace=True)

# %%
beero.head(5)
# Out:
#                            name     type  abv  astringency  body  alcohol  \
# 0                         Amber  Altbier  5.3           13    32        9
# 1                    Double Bag  Altbier  7.2           12    57       18
# 2                Long Trail Ale  Altbier  5.0           14    37        6
# 3                  Doppelsticke  Altbier  8.5           13    55       31
# 4  Sleigh'r Dark Doüble Alt Ale  Altbier  7.2           25    51       26
#
#    bitter  sweet  sour  salty  ...  hoppy  spices  malty  review_aroma  \
# 0      47     74    33      0  ...     57       8    111      3.498994
# 1      33     55    16      0  ...     35      12     84      3.798337
# 2      42     43    11      0  ...     54       4     62      3.409814
# 3      47    101    18      1  ...     40      16    119      4.148098
# 4      44     45     9      1  ...     51      20     95      3.625000
#
#    review_appearance  review_palate  review_taste    rating  \
# ...

# %%
beer.head(5)
# Out:
#              name     type  type_id  abv  rating  astringency  body  alcohol  \
# 0           Amber  Altbier        8  5.3    3.65           13    32        9
# 1      Double Bag  Altbier        8  7.2    3.90           12    57       18
# 2  Long Trail Ale  Altbier        8  5.0    3.58           14    37        6
# 3    Doppelsticke  Altbier        8  8.5    4.15           13    55       31
# 4          Scurry  Altbier        8  5.3    3.67           21    69       10
#
#    bitter  sweet  sour  salty  fruits  hoppy  spices  malty
# 0      47     74    33      0      33     57       8    111
# 1      33     55    16      0      24     35      12     84
# 2      42     43    11      0      10     54       4     62
# 3      47    101    18      1      49     40      16    119
# 4      63    120    14      0      19     36      15    218

# %%
beer["rating_aroma"]=beero["review_aroma"]

# %%
beer["rating_app"]=beero["review_appearance"]
beer["rating_palate"]=beero["review_palate"]
beer["rating_taste"]=beero["review_taste"]
beer["n_reviews"]=beero["number_of_reviews"]
#beer["rating"] = beero["rating"].combine_first(beer["rating"]).mean(axis=1)

# %%
temp_ratings = pd.DataFrame({
    'beero_rating': beero["rating"],
    'beer_rating': beer["rating"]
})

# Calculating the mean across the two columns
beer["rating"] = temp_ratings.mean(axis=1)

# %%
beer
# Out:
#                                              name           type  type_id  \
# 0                                           Amber        Altbier        8
# 1                                      Double Bag        Altbier        8
# 2                                  Long Trail Ale        Altbier        8
# 3                                    Doppelsticke        Altbier        8
# 4                                          Scurry        Altbier        8
# ...                                           ...            ...      ...
# 5658                          Red Nose Winter Ale  Winter Warmer       17
# 5659  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer       17
# 5660                         Fish Tale Winterfish  Winter Warmer       17
# 5661    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer       17
# 5662     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer       17
#
#       abv    rating  astringency  body  alcohol  bitter  sweet  ...  salty  \
# ...

# %%
beer.isna().sum()
# Out:
# name                2
# type                0
# type_id             0
# abv                 0
# rating              0
# astringency         0
# body                0
# alcohol             0
# bitter              0
# sweet               0
# sour                0
# salty               0
# fruits              0
# hoppy               0
# spices              0
# malty               0
# rating_aroma     2446
# rating_app       2446
# rating_palate    2446
# rating_taste     2446
# n_reviews        2446
# dtype: int64

# %%
beer["name"].dropna(inplace=True)

# %%
beer.isna().sum()
# Out:
# name                2
# type                0
# type_id             0
# abv                 0
# rating              0
# astringency         0
# body                0
# alcohol             0
# bitter              0
# sweet               0
# sour                0
# salty               0
# fruits              0
# hoppy               0
# spices              0
# malty               0
# rating_aroma     2446
# rating_app       2446
# rating_palate    2446
# rating_taste     2446
# n_reviews        2446
# dtype: int64

# %%
#beer.dropna(inplace=True)
beer.duplicated().sum()
# Out:
# 0

# %%
beer.isna().sum()
# Out:
# name                2
# type                0
# type_id             0
# abv                 0
# rating              0
# astringency         0
# body                0
# alcohol             0
# bitter              0
# sweet               0
# sour                0
# salty               0
# fruits              0
# hoppy               0
# spices              0
# malty               0
# rating_aroma     2446
# rating_app       2446
# rating_palate    2446
# rating_taste     2446
# n_reviews        2446
# dtype: int64

# %%
beer.shape
# Out:
# (5558, 21)

# %%
beer["type_id"].unique()
# Out:
# array([  8,  97,  98,  41,  40,  27,  43,  42,   2,   3,   4,   5,   6,
#         28, 117,   9,  10,  11,  29,  75,  30,  14,  44,  76,  45,  77,
#         78,  79,  80,  32,  33,  34,  35,  36,  37,  38,  81,  46,  54,
#         19,  55,  56,  20,  57,  58,  59,  60,  82,  61,  62,  63,  22,
#         21,  23,  24,  25, 118, 119, 120, 121,  83,  12,  47,  99,  48,
#         49,  50,  64,  65,  66,  68,  69,  70,  71,  72,  73,  84, 100,
#         51, 101,  52,  15,  85, 102,  16,  86, 122, 123, 124, 125,  89,
#         88,  90,  91,  92,  93,  94,  95, 103, 104, 105, 106, 107, 110,
#        111, 112, 113, 114, 108, 115, 126,  17], dtype=int64)

# %%
beer.nunique()
# Out:
# name             5317
# type              112
# type_id           112
# abv               229
# rating           2932
# astringency        73
# body              165
# alcohol           116
# bitter            141
# sweet             191
# sour              222
# salty              47
# fruits            185
# hoppy             156
# spices            155
# malty             217
# rating_aroma     2261
# rating_app       2192
# rating_palate    2263
# rating_taste     2291
# n_reviews         791
# dtype: int64

# %%
# beer["astringency"]=beer["astringency"]/beer["n_reviews"]
# beer["body"]=beer["body"]/beer["n_reviews"]
# beer["alcohol"]=beer["alcohol"]/beer["n_reviews"]
# beer["bitter"]=beer["bitter"]/beer["n_reviews"]
# beer["sweet"]=beer["sweet"]/beer["n_reviews"]
# beer["sour"]=beer["sour"]/beer["n_reviews"]
# beer["salty"]=beer["salty"]/beer["n_reviews"]
# beer["fruits"]=beer["fruits"]/beer["n_reviews"]
# beer["hoppy"]=beer["hoppy"]/beer["n_reviews"]
# beer["spices"]=beer["spices"]/beer["n_reviews"]
# beer["malty"]=beer["malty"]/beer["n_reviews"]

# %%
beer.head(5)
# Out:
#              name     type  type_id  abv    rating  astringency  body  \
# 0           Amber  Altbier        8  5.3  3.748541           13    32
# 1      Double Bag  Altbier        8  7.2  3.967152           12    57
# 2  Long Trail Ale  Altbier        8  5.0  3.705120           14    37
# 3    Doppelsticke  Altbier        8  8.5  4.077718           13    55
# 4          Scurry  Altbier        8  5.3  3.743854           21    69
#
#    alcohol  bitter  sweet  ...  salty  fruits  hoppy  spices  malty  \
# 0        9      47     74  ...      0      33     57       8    111
# 1       18      33     55  ...      0      24     35      12     84
# 2        6      42     43  ...      0      10     54       4     62
# 3       31      47    101  ...      1      49     40      16    119
# 4       10      63    120  ...      0      19     36      15    218
#
#    rating_aroma  rating_app  rating_palate  rating_taste  n_reviews
# ...

# %%
columns_to_round = ["rating", "astringency", "body", "alcohol", "bitter", 
                    "sweet", "sour", "salty", "fruits", "hoppy", "spices", "malty", "rating_aroma", "rating_app","rating_palate","rating_taste"]

# Applying the rounding to the specified columns
beer[columns_to_round] = beer[columns_to_round].apply(lambda x: round(x, 4))

# %%
beer.dropna(inplace=True)

# %%
beer.shape
# Out:
# (3110, 21)

# %%
beer_type=beer[["name","type","type_id"]]

# %%
beer_type
# Out:
#                     name                     type  type_id
# 0                  Amber                  Altbier        8
# 1             Double Bag                  Altbier        8
# 2         Long Trail Ale                  Altbier        8
# 3           Doppelsticke                  Altbier        8
# 4                 Scurry                  Altbier        8
# ...                  ...                      ...      ...
# 3192         Spring Mild  Mild Ale - English Pale       47
# 3193      Middling Spree  Mild Ale - English Pale       47
# 3194     First Born Mild  Mild Ale - English Pale       47
# 3195      Jacob Mac Mild  Mild Ale - English Pale       47
# 3196  Beauty and Justice  Mild Ale - English Pale       47
#
# [3110 rows x 3 columns]

# %%
beer.drop(columns=["name", "type", "n_reviews"], inplace=True)

# %%
beer
# Out:
#       type_id  abv  rating  astringency  body  alcohol  bitter  sweet  sour  \
# 0           8  5.3  3.7485           13    32        9      47     74    33
# 1           8  7.2  3.9672           12    57       18      33     55    16
# 2           8  5.0  3.7051           14    37        6      42     43    11
# 3           8  8.5  4.0777           13    55       31      47    101    18
# 4           8  5.3  3.7439           21    69       10      63    120    14
# ...       ...  ...     ...          ...   ...      ...     ...    ...   ...
# 3192       47  0.0  3.8900            0     9        1       6      7     3
# 3193       47  6.0  3.8550            0     0        0       0      0     0
# 3194       47  3.9  3.7108            0     0        0       0      0     0
# 3195       47  0.0  3.4997            4     4        1       2      3     0
# 3196       47  3.5  3.8039            6    21        3      17     23     4
#
# ...

# %%
# applicare tutti i modelli per vedere correlazione: prima al rating generale e poi ai rating particolari
# nel caso faccia fiasco, ripristinare i valori senza dividerli per il numero di recensioni
# nel caso neanche questo vada bene, cerchiamo di capire se il type_id può essere o un parametro o addirittura un target
# nel caso vada bene, facciamo subito machine learning e streamlit
# e poi alla fine pensiamo alle statistiche, e ci mettiamo insieme pure qualcos'altro. Adesso vatti a godere Diana e i mici.

# %%
#knn (GEN RATING)

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split

features = beer.drop(columns=["rating_aroma","rating_app","rating_palate","rating_taste","rating","type_id"]) #modo veloce per dire tutte le colonne tranne target
target = beer["rating"]

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size= 0.20, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.neighbors import KNeighborsRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler

standardizer=StandardScaler()
standardizer.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_st = standardizer.transform(x_train)
x_test_st= standardizer.transform(x_test)
pd.DataFrame(x_train_st, columns=x_train.columns)
# Out:
#            abv  astringency      body   alcohol    bitter     sweet      sour  \
# 0    -0.514698     1.781018 -0.675178 -0.541214 -0.844739 -0.925537  1.532337
# 1    -0.671579    -0.099278 -1.131484 -0.341923 -0.270574 -1.093942 -0.824800
# 2    -0.514698     2.379294  0.602478  0.388809  1.949530 -0.336121  0.648411
# 3     0.465805    -0.099278 -0.127612  0.056658  0.992588 -0.729065  0.621625
# 4    -0.946120    -0.270213 -1.085854 -0.408354 -0.347130 -1.009740 -0.235516
# ...        ...          ...       ...       ...       ...       ...       ...
# 2483 -0.318597    -0.697553  0.374325 -0.408354 -0.270574 -0.167716 -0.771229
# 2484  0.073604    -0.099278 -0.036350 -0.009772 -0.461963  0.954981  0.353769
# 2485  0.230485     0.328062 -0.081981 -0.209063  1.566753 -0.588728  0.059127
# 2486 -0.318597    -0.013810  0.146172 -0.275493  0.188758  0.337497 -0.503372
# 2487 -0.553918     0.071658  1.743242 -0.408354  3.021305 -0.111582 -0.744443
#
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=10)
knn.fit(x_train_st,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
knn.score(x_test_st,y_test)
# Out:
# 0.2870479530994394

# %%
from sklearn.metrics import mean_squared_error
pred=knn.predict(x_test_st)
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.2793637266406292

# %%
knn.predict(x_test_st)
# Out:
# array([3.60205, 3.63774, 3.78181, 3.7238 , 3.6513 , 3.58607, 3.64658,
#        3.80112, 3.72565, 3.73   , 3.88722, 3.39036, 3.3137 , 3.59182,
#        3.76599, 3.70483, 3.6607 , 3.90773, 3.61477, 3.40543, 3.77312,
#        3.7507 , 3.76835, 3.92746, 3.29875, 3.69218, 3.81603, 3.7173 ,
#        3.66653, 3.21986, 3.74611, 3.76572, 3.62583, 3.70185, 3.2681 ,
#        3.75752, 3.72707, 3.61449, 3.55261, 3.84392, 3.76014, 3.71235,
#        3.69074, 3.78511, 3.86808, 3.92435, 3.88342, 3.81293, 3.77907,
#        3.34085, 3.70276, 3.66807, 3.9467 , 3.94086, 3.51755, 3.73625,
#        3.53574, 3.89675, 3.50396, 3.50518, 3.61377, 3.8009 , 3.52793,
#        3.69928, 3.64166, 3.84218, 3.51597, 3.69369, 3.26494, 3.51256,
#        3.63769, 3.73434, 3.75021, 3.76717, 3.643  , 3.38905, 3.62782,
#        3.42945, 3.85475, 3.41544, 3.73566, 3.7189 , 3.72644, 3.72846,
#        3.48187, 3.55338, 3.46521, 3.7506 , 3.3381 , 3.74884, 3.51426,
# ...

# %%
y_test
# Out:
# 2055    3.4089
# 851     4.0485
# 2290    3.8267
# 224     3.6938
# 554     2.9500
#          ...
# 2976    3.9050
# 3122    3.5466
# 2789    3.6975
# 14      3.9782
# 1066    3.8044
# Name: rating, Length: 622, dtype: float64

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
pred= knn.predict(x_test)
mean_squared_error(y_test,pred)
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# c:\Users\valte\Documents\Bootcamp\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(
# 0.3788015561489103

# %%
beerknn=pd.DataFrame(x_test)
beerknn["pred"]=pred

# %%
beerknn["real"]=y_test

# %%
beerknn
# Out:
#       abv  astringency  body  alcohol  bitter  sweet  sour  salty  fruits  \
# 2055  4.0           30    43       13      61     30    17      2      22
# 851   7.8           10    47        8      65     36     4      0       6
# 2290  4.5           35    30        3      46     32    16      6      18
# 224   4.3           19    47       12      71     73    28      0      33
# 554   5.2            6    27        8      16     31     6      0       5
# ...   ...          ...   ...      ...     ...    ...   ...    ...     ...
# 2976  6.4           40    31        5       4     65   185      0     100
# 3122  4.0            6    26        2      21     39     5      0       4
# 2789  5.1           14    40        2      45     34     9      0       8
# 14    7.7           24    44       27      79     73    88      2     114
# 1066  8.0            7    51       26      17     82    27      0      49
#
#       hoppy  spices  malty     pred    real
# ...

# %%
beer
# Out:
#       type_id  abv  rating  astringency  body  alcohol  bitter  sweet  sour  \
# 0           8  5.3  3.7485           13    32        9      47     74    33
# 1           8  7.2  3.9672           12    57       18      33     55    16
# 2           8  5.0  3.7051           14    37        6      42     43    11
# 3           8  8.5  4.0777           13    55       31      47    101    18
# 4           8  5.3  3.7439           21    69       10      63    120    14
# ...       ...  ...     ...          ...   ...      ...     ...    ...   ...
# 3192       47  0.0  3.8900            0     9        1       6      7     3
# 3193       47  6.0  3.8550            0     0        0       0      0     0
# 3194       47  3.9  3.7108            0     0        0       0      0     0
# 3195       47  0.0  3.4997            4     4        1       2      3     0
# 3196       47  3.5  3.8039            6    21        3      17     23     4
#
# ...

# %%
corr=np.abs(beer.corr())
mask=np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)]=True

# %%
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask,  vmax=1,square=True, linewidths=.8, cbar_kws={"shrink": .5},annot = corr)
plt.show()

# %%
#LR

from sklearn.datasets import  fetch_california_housing
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
features = beer.drop(columns=["rating_aroma","rating_app","rating_palate","rating_taste","rating","type_id"]) #modo veloce per dire tutte le colonne tranne target
target = beer["rating"]

x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
standardizer=StandardScaler()

standardizer.fit(x_train)
x_train_st = standardizer.transform(x_train)
x_test_st= standardizer.transform(x_test)
pd.DataFrame(x_train_st, columns=x_train.columns)
# Out:
#            abv  astringency      body   alcohol    bitter     sweet      sour  \
# 0    -0.514698     1.781018 -0.675178 -0.541214 -0.844739 -0.925537  1.532337
# 1    -0.671579    -0.099278 -1.131484 -0.341923 -0.270574 -1.093942 -0.824800
# 2    -0.514698     2.379294  0.602478  0.388809  1.949530 -0.336121  0.648411
# 3     0.465805    -0.099278 -0.127612  0.056658  0.992588 -0.729065  0.621625
# 4    -0.946120    -0.270213 -1.085854 -0.408354 -0.347130 -1.009740 -0.235516
# ...        ...          ...       ...       ...       ...       ...       ...
# 2483 -0.318597    -0.697553  0.374325 -0.408354 -0.270574 -0.167716 -0.771229
# 2484  0.073604    -0.099278 -0.036350 -0.009772 -0.461963  0.954981  0.353769
# 2485  0.230485     0.328062 -0.081981 -0.209063  1.566753 -0.588728  0.059127
# 2486 -0.318597    -0.013810  0.146172 -0.275493  0.188758  0.337497 -0.503372
# 2487 -0.553918     0.071658  1.743242 -0.408354  3.021305 -0.111582 -0.744443
#
# ...

# %%
x_train_st=pd.DataFrame(x_train_st, columns=x_train.columns)
x_test_st=pd.DataFrame(x_test_st, columns=x_test.columns)

# %%
LR = LinearRegression()
LR.fit(x_train_st,y_train)
pred=LR.predict(x_test_st)
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.30189971581776553

# %%
LR.score(x_test_st, y_test)
# Out:
# 0.1673821873117285

# %%
# LR
# r2=0.0585
# me=0.32

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
tree=DecisionTreeRegressor(max_depth=10)

# %%
features = beer.drop(columns=["rating_aroma","rating_app","rating_palate","rating_taste","rating","type_id"]) 
target = beer["rating"]
x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
standardizer=StandardScaler()
standardizer.fit(x_train)
x_train_st = standardizer.transform(x_train)
x_test_st= standardizer.transform(x_test)
pd.DataFrame(x_train_st, columns=x_train.columns)
# Out:
#            abv  astringency      body   alcohol    bitter     sweet      sour  \
# 0    -0.514698     1.781018 -0.675178 -0.541214 -0.844739 -0.925537  1.532337
# 1    -0.671579    -0.099278 -1.131484 -0.341923 -0.270574 -1.093942 -0.824800
# 2    -0.514698     2.379294  0.602478  0.388809  1.949530 -0.336121  0.648411
# 3     0.465805    -0.099278 -0.127612  0.056658  0.992588 -0.729065  0.621625
# 4    -0.946120    -0.270213 -1.085854 -0.408354 -0.347130 -1.009740 -0.235516
# ...        ...          ...       ...       ...       ...       ...       ...
# 2483 -0.318597    -0.697553  0.374325 -0.408354 -0.270574 -0.167716 -0.771229
# 2484  0.073604    -0.099278 -0.036350 -0.009772 -0.461963  0.954981  0.353769
# 2485  0.230485     0.328062 -0.081981 -0.209063  1.566753 -0.588728  0.059127
# 2486 -0.318597    -0.013810  0.146172 -0.275493  0.188758  0.337497 -0.503372
# 2487 -0.553918     0.071658  1.743242 -0.408354  3.021305 -0.111582 -0.744443
#
# ...

# %%
tree.fit(x_train_st,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
pred=tree.predict(x_test_st)
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.3582249069143066

# %%
tree.score(x_test_st, y_test)
# Out:
# -0.1722813244804322

# %%
beer_type
# Out:
#                     name                     type  type_id
# 0                  Amber                  Altbier        8
# 1             Double Bag                  Altbier        8
# 2         Long Trail Ale                  Altbier        8
# 3           Doppelsticke                  Altbier        8
# 4                 Scurry                  Altbier        8
# ...                  ...                      ...      ...
# 3192         Spring Mild  Mild Ale - English Pale       47
# 3193      Middling Spree  Mild Ale - English Pale       47
# 3194     First Born Mild  Mild Ale - English Pale       47
# 3195      Jacob Mac Mild  Mild Ale - English Pale       47
# 3196  Beauty and Justice  Mild Ale - English Pale       47
#
# [3110 rows x 3 columns]

# %%
beer_type=beer_type.groupby(["type"]).agg({"type_id":"mean"})

# %%
beer_type["type_id"] = beer_type["type_id"].astype(int)

# %%
beer_type
# Out:
#                                                     type_id
# type
# Altbier                                                   8
# Barleywine - American                                    97
# Barleywine - English                                     98
# Bitter - English                                         40
# Bitter - English Extra Special / Strong Bitter ...       41
# ...                                                     ...
# Lambic - Gueuze                                         120
# Lambic - Traditional                                    121
# Low Alcohol Beer                                         83
# Mild Ale - English Dark                                  12
# Mild Ale - English Pale                                  47
#
# [63 rows x 1 columns]

# %%
beer_type = beer_type.sort_values(by="type_id", ascending=True)

# %%
beer_type.head(63)
# Out:
#                       type_id
# type
# Bock - Doppelbock           2
# Bock - Eisbock              3
# Bock - Maibock              4
# Bock - Traditional          5
# Bock - Weizenbock           6
# ...                       ...
# Brett Beer                117
# Lambic - Faro             118
# Lambic - Fruit            119
# Lambic - Gueuze           120
# Lambic - Traditional      121
#
# [63 rows x 1 columns]

# %%
beer_type
# Out:
#                       type_id
# type
# Bock - Doppelbock           2
# Bock - Eisbock              3
# Bock - Maibock              4
# Bock - Traditional          5
# Bock - Weizenbock           6
# ...                       ...
# Brett Beer                117
# Lambic - Faro             118
# Lambic - Fruit            119
# Lambic - Gueuze           120
# Lambic - Traditional      121
#
# [63 rows x 1 columns]

# %%
birra=beer.drop(columns=["rating_aroma","rating_app","rating_palate","rating_taste","rating","abv"])

# %%
birra
# Out:
#       type_id  astringency  body  alcohol  bitter  sweet  sour  salty  fruits  \
# 0           8           13    32        9      47     74    33      0      33
# 1           8           12    57       18      33     55    16      0      24
# 2           8           14    37        6      42     43    11      0      10
# 3           8           13    55       31      47    101    18      1      49
# 4           8           21    69       10      63    120    14      0      19
# ...       ...          ...   ...      ...     ...    ...   ...    ...     ...
# 3192       47            0     9        1       6      7     3      0       0
# 3193       47            0     0        0       0      0     0      0       0
# 3194       47            0     0        0       0      0     0      0       0
# 3195       47            4     4        1       2      3     0      0       0
# 3196       47            6    21        3      17     23     4      0       5
#
#       hoppy  spices  malty
# ...

# %%
features = birra.drop(columns=["type_id", "fruits", "sour"]) 
target = beer["type_id"]
x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
birra
# Out:
#       type_id  astringency  body  alcohol  bitter  sweet  sour  salty  fruits  \
# 0           8           13    32        9      47     74    33      0      33
# 1           8           12    57       18      33     55    16      0      24
# 2           8           14    37        6      42     43    11      0      10
# 3           8           13    55       31      47    101    18      1      49
# 4           8           21    69       10      63    120    14      0      19
# ...       ...          ...   ...      ...     ...    ...   ...    ...     ...
# 3192       47            0     9        1       6      7     3      0       0
# 3193       47            0     0        0       0      0     0      0       0
# 3194       47            0     0        0       0      0     0      0       0
# 3195       47            4     4        1       2      3     0      0       0
# 3196       47            6    21        3      17     23     4      0       5
#
#       hoppy  spices  malty
# ...

# %%
LR = LogisticRegression()
LR.fit(x_train_st,y_train)
pred=LR.predict(x_test_st)
LR.score(x_test_st, y_test)
# Out:
# c:\Users\valte\Documents\Bootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.43086816720257237

# %%
birralr=pd.DataFrame(x_test)
birralr["pred"]=pred
birralr["real"]=y_test
birralr
# Out:
#       astringency  body  alcohol  bitter  sweet  salty  hoppy  spices  malty  \
# 2055           30    43       13      61     30      2     91       6     84
# 851            10    47        8      65     36      0     18      27    100
# 2290           35    30        3      46     32      6     66       9     72
# 224            19    47       12      71     73      0     78      14    122
# 554             6    27        8      16     31      0     15       1     80
# ...           ...   ...      ...     ...    ...    ...    ...     ...    ...
# 2976           40    31        5       4     65      0      7       2      5
# 3122            6    26        2      21     39      0     24       5     70
# 2789           14    40        2      45     34      0     25       4     80
# 14             24    44       27      79     73      2     92       9     51
# 1066            7    51       26      17     82      0      9      22     74
#
#       pred  real
# 2055    57    55
# ...

# %%
corr=np.abs(birra.corr())
mask=np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)]=True

# %%
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask,  vmax=1,square=True, linewidths=.8, cbar_kws={"shrink": .5},annot = corr)
plt.show()

# %%
features = birra.drop(columns=["type_id"]) 
target = beer["type_id"]
x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
tree=DecisionTreeRegressor(max_depth=10)
standardizer=StandardScaler()
standardizer.fit(x_train)
x_train_st = standardizer.transform(x_train)
x_test_st= standardizer.transform(x_test)
pd.DataFrame(x_train_st, columns=x_train.columns)
# Out:
#       astringency      body   alcohol    bitter     sweet      sour     salty  \
# 0        1.781018 -0.675178 -0.541214 -0.844739 -0.925537  1.532337 -0.498192
# 1       -0.099278 -1.131484 -0.341923 -0.270574 -1.093942 -0.824800 -0.029748
# 2        2.379294  0.602478  0.388809  1.949530 -0.336121  0.648411  5.591579
# 3       -0.099278 -0.127612  0.056658  0.992588 -0.729065  0.621625 -0.029748
# 4       -0.270213 -1.085854 -0.408354 -0.347130 -1.009740 -0.235516  0.438695
# ...           ...       ...       ...       ...       ...       ...       ...
# 2483    -0.697553  0.374325 -0.408354 -0.270574 -0.167716 -0.771229 -0.498192
# 2484    -0.099278 -0.036350 -0.009772 -0.461963  0.954981  0.353769 -0.498192
# 2485     0.328062 -0.081981 -0.209063  1.566753 -0.588728  0.059127  0.438695
# 2486    -0.013810  0.146172 -0.275493  0.188758  0.337497 -0.503372 -0.029748
# 2487     0.071658  1.743242 -0.408354  3.021305 -0.111582 -0.744443 -0.029748
#
# ...

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
pred=tree.predict(x_test)
tree.score(x_test, y_test)
# Out:
# 0.2617847094670799

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
features = birra.drop(columns=["type_id"]) 
target = beer["type_id"]
x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
standardizer=StandardScaler()
standardizer.fit(x_train)
x_train_st = standardizer.transform(x_train)
x_test_st= standardizer.transform(x_test)
pd.DataFrame(x_train_st, columns=x_train.columns)
# Out:
#       astringency      body   alcohol    bitter     sweet      sour     salty  \
# 0        1.781018 -0.675178 -0.541214 -0.844739 -0.925537  1.532337 -0.498192
# 1       -0.099278 -1.131484 -0.341923 -0.270574 -1.093942 -0.824800 -0.029748
# 2        2.379294  0.602478  0.388809  1.949530 -0.336121  0.648411  5.591579
# 3       -0.099278 -0.127612  0.056658  0.992588 -0.729065  0.621625 -0.029748
# 4       -0.270213 -1.085854 -0.408354 -0.347130 -1.009740 -0.235516  0.438695
# ...           ...       ...       ...       ...       ...       ...       ...
# 2483    -0.697553  0.374325 -0.408354 -0.270574 -0.167716 -0.771229 -0.498192
# 2484    -0.099278 -0.036350 -0.009772 -0.461963  0.954981  0.353769 -0.498192
# 2485     0.328062 -0.081981 -0.209063  1.566753 -0.588728  0.059127  0.438695
# 2486    -0.013810  0.146172 -0.275493  0.188758  0.337497 -0.503372 -0.029748
# 2487     0.071658  1.743242 -0.408354  3.021305 -0.111582 -0.744443 -0.029748
#
# ...

# %%
BAG=BaggingRegressor(DecisionTreeRegressor(max_depth=10),
                     n_estimators=100,
                     max_samples=1000,
                     bootstrap=True)

# %%
BAG.fit(x_train_st,y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(max_depth=10),
#                  max_samples=1000, n_estimators=100)

# %%
pred=BAG.predict(x_test_st)
BAG.score(x_test_st,y_test)
# Out:
# 0.4694348921700382

# %%
forest=RandomForestRegressor(n_estimators=100,
                             max_depth=20)

# %%
forest.fit(x_train_st,y_train)
# Out:
# RandomForestRegressor(max_depth=20)

# %%
pred=forest.predict(x_test_st)
forest.score(x_test_st,y_test)
# Out:
# 0.5038226650241289

# %%
ADA=AdaBoostRegressor(DecisionTreeRegressor(max_depth=20),
                      n_estimators=100)

# %%
ADA.fit(x_train_st, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),
#                   n_estimators=100)

# %%
pred=ADA.predict(x_test_st)
ADA.score(x_test_st,y_test)
# Out:
# 0.395800241380713

# %%
GB= GradientBoostingRegressor(n_estimators=100,
                              max_depth=20)

# %%
GB.fit(x_train_st, y_train)
# Out:
# GradientBoostingRegressor(max_depth=20)

# %%
pred=GB.predict(x_test_st)
GB.score(x_test_st,y_test)
# Out:
# 0.17932256753653764

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
grid={"n_estimators":[100,1000],
      "estimator__max_depth":[50,100]}

# %%
forest=RandomForestRegressor(n_estimators=100,
                             max_depth=20)
model=GridSearchCV(estimator=ADA,param_grid=grid,cv=5)
model.fit(x_train_st,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=20),
#                                          n_estimators=100),
#              param_grid={'estimator__max_depth': [50, 100],
#                          'n_estimators': [100, 1000]})

# %%
model.score(x_test_st,y_test)
# Out:
# 0.3452352875719622

# %%
# !pip install shap
# Out:
# ...
#    ---------------------------------------- 0.0/455.5 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/455.5 kB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 256.0/455.5 kB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 440.3/455.5 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 455.5/455.5 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

from sklearn.feature_selection import mutual_info_regression
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
features = beer.drop(columns=["rating_aroma","rating_app","rating_palate","rating_taste","rating","type_id"]) 
target = beer["rating"]
x_train,x_test,y_train,y_test=train_test_split(features, target, test_size=0.20,random_state=0)

# %%
def score_model(x_train_st, y_train, model):
    log_y = np.log(y_train)
    scores = cross_val_score(
        model, x_train_st, log_y, cv=8, scoring='neg_mean_squared_error'
    )
    scores = np.mean(abs(scores))
    scores = np.sqrt(scores)
    return scores

# %%
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(),AdaBoostRegressor(), GradientBoostingRegressor(), XGBRegressor()]

model_scores = []
for model in models:
    model_score = score_model(x_train_st, y_train, model)
    model_scores.append(model_score)
    print(model,'RMSE score:', model_score)
    print('\n')
    
print("Best score (RMSE):", min(model_scores))
print("Best model:", models[model_scores.index(min(model_scores))])
# Out:
# LinearRegression() RMSE score: 0.08726938778707054
#
#
# DecisionTreeRegressor() RMSE score: 0.11514911828946416
#
#
# RandomForestRegressor() RMSE score: 0.08065104872869236
#
#
# AdaBoostRegressor() RMSE score: 0.09180489074268555
#
#
# GradientBoostingRegressor() RMSE score: 0.08159370510846299
#
#
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
forest=RandomForestRegressor(n_estimators=100,
                             max_depth=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 forest=RandomForestRegressor(n_estimators=100,
#       2                              max_depth=20)
#
# NameError: name 'RandomForestRegressor' is not defined
